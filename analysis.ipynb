# %%
import pandas as pd

# %%
df = pd.read_csv("news_data.csv")

# remove null
df.dropna(inplace=True)

# format date
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

print(df.head())
# Out:
#                                                title          source  \
# 0  “Most Trolled Person In The Entire World”: Meg...  Boredpanda.com
# 1  Top Business & Market Headlines Today — BL Mor...    BusinessLine
# 2  Trump administration looks to Ford, GM in WWII...   New York Post
# 3  Precore Gold Completes Data Compilation and Re...  Financial Post
# 4  Memo: Condé Nast is shuttering Self magazine, ...  Mediagazer.com
#
#                 publishedAt  category
# 0 2026-04-16 15:29:52+00:00  business
# 1 2026-04-16 15:26:46+00:00  business
# 2 2026-04-16 15:26:30+00:00  business
# 3 2026-04-16 15:26:02+00:00  business
# 4 2026-04-16 15:25:02+00:00  business

# %%
df = pd.read_csv("news_data.csv")

category_counts = df['category'].value_counts()
category_counts
# Out:
# category
# entertainment    489
# business         469
# technology       467
# science          450
# sports           446
# health           428
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

category_counts.plot(kind='bar')
plt.title("News Category Distribution")
plt.show()

# %%
category_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title("Category Share")
plt.show()

# %%
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

df['date'] = df['publishedAt'].dt.date

df.groupby(['date', 'category']).size().unstack().plot()
plt.title("Trend Over Time")
plt.show()

# %% [markdown]
# 1. Sports category sabse zyada hai
# 2. Technology news increase ho rahi hai
# 3. Business stable hai

# %%
df['source'].value_counts()
# Out:
# source
# Financial Post             305
# GlobeNewswire              161
# Fox News                   107
# Ibtimes.com.au              90
# The Times of India          90
#                           ...
# Knoxville News Sentinel      1
# The Next Web                 1
# PCMag.com                    1
# Help Net Security            1
# Elegantthemes.com            1
# Name: count, Length: 220, dtype: int64

# %%
df['source'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='source'>

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

df['sentiment'] = df['title'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df['sentiment'].hist()
# Out:
# <Axes: >

# %%
from collections import Counter

words = " ".join(df['title']).lower().split()
Counter(words).most_common(10)
# Out:
# [('to', 822),
#  ('the', 769),
#  ('in', 731),
#  ('and', 588),
#  ('of', 497),
#  ('for', 496),
#  ('a', 383),
#  ('on', 268),
#  ('is', 245),
#  ('as', 237)]

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

words = [word for word in words if word not in ENGLISH_STOP_WORDS]
Counter(words).most_common(10)
# Out:
# [('ai', 195),
#  ('2026', 176),
#  ('new', 110),
#  ('world', 95),
#  ('&', 88),
#  ('million', 87),
#  ('says', 77),
#  ('stock', 72),
#  ('news', 72),
#  ('—', 71)]

# %%
print(streamlit.__version__)
print(pandas.__version__)
print(requests.__version__)
print(matplotlib.__version__)
print(seaborn.__version__)
print(streamlit_autorefresh.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(streamlit.__version__)
#       2 print(pandas.__version__)
#       3 print(requests.__version__)
#
# NameError: name 'streamlit' is not defined
